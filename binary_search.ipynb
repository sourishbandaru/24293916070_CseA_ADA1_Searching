# %%
import pandas as pd
import matplotlib.pyplot as plt   

# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\souri\OneDrive\Desktop\Sourish\College\ADA\Binary\binary_search_results.txt")

# %%
df
# Out:
#     size   time
# 0     10  0.002
# 1     50  0.000
# 2    100  0.001
# 3   1000  0.004
# 4   3000  0.000
# 5   5000  0.002
# 6   7000  0.001
# 7  10000  0.001

# %%
plt.figure(figsize=(8,5))

plt.plot(df["size"], df["time"], marker='o', linestyle='-', label="Binary Search Time")

plt.xlabel("Input Size (n)")
plt.ylabel("Total Time (seconds)")
plt.title("Binary Search Performance")
plt.legend()
plt.grid(True)

plt.show()
